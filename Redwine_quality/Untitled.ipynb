# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.sample(25)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 931             7.4             0.610         0.01            2.00      0.074
# 1387            7.4             0.640         0.07            1.80      0.100
# 1150            8.2             0.330         0.32            2.80      0.067
# 161             7.6             0.680         0.02            1.30      0.072
# 398            11.5             0.590         0.59            2.60      0.087
# 264            12.5             0.560         0.49            2.40      0.064
# 583            12.0             0.280         0.49            1.90      0.074
# 17              8.1             0.560         0.28            1.70      0.368
# 1163            9.0             0.785         0.24            1.70      0.078
# 605             8.3             0.600         0.13            2.60      0.085
# 1329            7.4             0.600         0.26            2.10      0.083
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
# So, the quality of the wine highly depends on volatile acidity and alcohol.
# It depends comparitively low on fixed acidity, citric acid, chlorides, total sulfur dioxide, density, sulphates.
# The dependency of the quality of wine is very low on residual sugar, free sulfur dioxide, pH.

# %%
df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
# The quality of wine increases on increasing citric acid, sulphates, alcohol.
# The quality of wine increases on decreasing volatile acidity, chlorides, density, ph.
# The rest of the things varies non-uniformly, so we cannot say anything at this point.

# %%
df['quality'].value_counts().plot(kind = 'pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x='quality', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
# This shows that a very few quantity of red wine has a good quality whose rating is 8 and bad quality of rating 3 and 4.
# Majority of the wine(approx 1300) is of average quality with 5-6 ratings.

# %%
sns.scatterplot(df['alcohol'])
# Out:
# <Axes: ylabel='alcohol'>

# %%
# Majority of the wine contains 9-11% of alcohol.

# %%
sns.boxplot(x='alcohol', data=df)
# Out:
# <Axes: xlabel='alcohol'>

# %%
# The average range of the percentage of alcohol in red wine is 9.5-11%.
# Less than 25% of the wine contains 9.5% of alcohol in it.
# Less than 75% of the wine contains 11% of alcohol in it.

# %%
sns.boxplot(x='fixed acidity', data=df)
# Out:
# <Axes: xlabel='fixed acidity'>

# %%
sns.scatterplot(df['fixed acidity'])
# Out:
# <Axes: ylabel='fixed acidity'>

# %%
# The percentage of 'fixed acidity' in majority of the wine is lies between 6-10%.

# %%
sns.scatterplot(df['volatile acidity'])
# Out:
# <Axes: ylabel='volatile acidity'>

# %%
# According to the above scatterplot, we came to know that the volatile acidity should be less than 1% in red wine.

# %%
sns.scatterplot(df['citric acid'])
# Out:
# <Axes: ylabel='citric acid'>

# %%
# Less amount of citric acid is used.

# %%
sns.scatterplot(df['residual sugar'])
# Out:
# <Axes: ylabel='residual sugar'>

# %%
# Only 1-3% of the residual sugar is used.

# %%
sns.scatterplot(df['chlorides'])
# Out:
# <Axes: ylabel='chlorides'>

# %%
# Less than 0.1% chlorides are used in red wine.

# %%
sns.scatterplot(df['free sulfur dioxide'])
# Out:
# <Axes: ylabel='free sulfur dioxide'>

# %%
# Majority number of wine contains 1-20% of free sulfur dioxide, whereas 20-40% alcohol used in comparitively less number of wine.

# %%
sns.scatterplot(df['total sulfur dioxide'])
# Out:
# <Axes: ylabel='total sulfur dioxide'>

# %%
sns.scatterplot(df['density'])
# Out:
# <Axes: ylabel='density'>

# %%
sns.scatterplot(df['pH'])
# Out:
# <Axes: ylabel='pH'>

# %%
# This shows that most 0f the wines are acidic as the majority of the wine has pH range of 3-3.6.

# %%
sns.scatterplot(df['sulphates'])
# Out:
# <Axes: ylabel='sulphates'>

# %%
# The composition of sulphates for majority of the wine is from 0.50 to 1.00

# %%
sns.barplot(x='quality', y='alcohol', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
# The quality of wine is at it's peek i.e. 8 when approximately 12% of the alcohol is used.

# %%
sns.barplot(x='quality', y='fixed acidity', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %%
# It is a non-uniform variation

# %%
sns.barplot(x='quality', y='volatile acidity', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
# Decreasing the volatile acidity enhances the quality of the wine. But if you observe the plot for the quality rating 8 it is not true. This variation might be because of some other composition.

# %%
df.corr()['volatile acidity']
# Out:
# fixed acidity          -0.256131
# volatile acidity        1.000000
# citric acid            -0.552496
# residual sugar          0.001918
# chlorides               0.061298
# free sulfur dioxide    -0.010504
# total sulfur dioxide    0.076470
# density                 0.022026
# pH                      0.234937
# sulphates              -0.260987
# alcohol                -0.202288
# quality                -0.390558
# Name: volatile acidity, dtype: float64

# %%
# This variation might be occurring due to the following compositions as volatile acidity highly depends on these:
#    1. fixed acidity
#    2. citric acid
#    3. pH
#    4. sulphates
#    5. alcohol

# %%
sns.scatterplot(x='volatile acidity', y='fixed acidity', data=df)
# Out:
# <Axes: xlabel='volatile acidity', ylabel='fixed acidity'>

# %%
sns.scatterplot(x='volatile acidity', y='citric acid', data=df)
# Out:
# <Axes: xlabel='volatile acidity', ylabel='citric acid'>

# %%
sns.scatterplot(x='volatile acidity', y='pH', data=df)
# Out:
# <Axes: xlabel='volatile acidity', ylabel='pH'>

# %%
sns.scatterplot(x='volatile acidity', y='sulphates', data=df)
# Out:
# <Axes: xlabel='volatile acidity', ylabel='sulphates'>

# %%
sns.scatterplot(x='volatile acidity', y='alcohol', data=df)
# Out:
# <Axes: xlabel='volatile acidity', ylabel='alcohol'>

# %%
sns.barplot(x='quality', y='pH', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
# From the above bar plot it is clear that a wine is acidic and it's pH range is 3.0-3.5. 
# Also, it shows a decreasing trend i.e. on decreasing the pH(slighlty), the quality of wine increases.

# %%
df.corr()['pH']
# Out:
# fixed acidity          -0.682978
# volatile acidity        0.234937
# citric acid            -0.541904
# residual sugar         -0.085652
# chlorides              -0.265026
# free sulfur dioxide     0.070377
# total sulfur dioxide   -0.066495
# density                -0.341699
# pH                      1.000000
# sulphates              -0.196648
# alcohol                 0.205633
# quality                -0.057731
# Name: pH, dtype: float64

# %%
# pH highly depends on fixed acidity, citric acid and density.
# The pH of wine also depends on volatile acidity, chlorides and sulphates but it's dependacy is comparitively low on these.

# %%
sns.barplot(x='quality', y='citric acid', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
# The quality of wine show incresing trend with citric acid i.e. quality of the wine increases with increase in citric acid.

# %%
df.corr()['citric acid']
# Out:
# fixed acidity           0.671703
# volatile acidity       -0.552496
# citric acid             1.000000
# residual sugar          0.143577
# chlorides               0.203823
# free sulfur dioxide    -0.060978
# total sulfur dioxide    0.035533
# density                 0.364947
# pH                     -0.541904
# sulphates               0.312770
# alcohol                 0.109903
# quality                 0.226373
# Name: citric acid, dtype: float64

# %%
# citric acid highly depends on fixed acidity, volatile acidity, pH, sulphates.

# %%
sns.barplot(x='quality', y='residual sugar', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='residual sugar'>

# %%
# It shows abnormal trend.

# %%
sns.barplot(x='quality', y='chlorides', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='chlorides'>

# %%
# The quality of wine increases on decreasing the concentration of chlorides.

# %%
sns.barplot(x='quality', y='free sulfur dioxide', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='free sulfur dioxide'>

# %%
# It shows an abnormal trend.

# %%
sns.barplot(x='quality', y='total sulfur dioxide', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='total sulfur dioxide'>

# %%
# It also shows an abnormal trend but when the concentration of total sulfur dioxide is around 35 then the qulaity rating for the wine is 8.

# %%
df.corr()['total sulfur dioxide']
# Out:
# fixed acidity          -0.113181
# volatile acidity        0.076470
# citric acid             0.035533
# residual sugar          0.203028
# chlorides               0.047400
# free sulfur dioxide     0.667666
# total sulfur dioxide    1.000000
# density                 0.071269
# pH                     -0.066495
# sulphates               0.042947
# alcohol                -0.205654
# quality                -0.185100
# Name: total sulfur dioxide, dtype: float64

# %%
# total sulfur dioxide depends on residual sugar, free sulfur dioxide and alcohol.

# %%
sns.barplot(x='quality', y='density', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='density'>

# %%
sns.barplot(x='quality', y='sulphates', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='sulphates'>

# %%
# The quality of wine increases on increasing the concentration of sulphates.
